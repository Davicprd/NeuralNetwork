# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import PIL


from tensorflow import keras
from tensorflow.keras import layers # type: ignore
from tensorflow.keras.models import Sequential # type: ignore
from keras.models import load_model
import pathlib

# %%
#Pega o diretório com as imagens usando Pathlib
data_dir = pathlib.Path("C:/Users/samuc/Downloads/flower_images") #Urls "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"  https://www.kaggle.com/datasets/kausthubkannan/5-flower-types-classification-dataset/data
 
#Define o tamanho dos batchs e o tamnaho padrão das imagens / Define qual parte das imagens será de Treinamento e qual será de Validação 
batch_size = 32
img_height = 128
img_width = 128
train_ds = tf.keras.utils.image_dataset_from_directory(data_dir, validation_split=0.2, subset="training", seed=123, image_size=(img_height, img_width), batch_size=batch_size)
val_ds = tf.keras.utils.image_dataset_from_directory(data_dir, validation_split=0.2, subset="validation", seed=123, image_size=(img_height, img_width), batch_size=batch_size)
class_names = train_ds.class_names
num_classes = len(class_names)

#Insere os dados na memória cache e sobrepõe o pré-processamento dos dados e a execução do modelo durante a fase de treinamento 
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

#Faz o aumento do Dataset modificando as imagens existentes 
data_augmentation = Sequential(
  [
    layers.RandomFlip("horizontal", input_shape=(img_height, img_width, 3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

base_model = tf.keras.applications.MobileNetV2(input_shape=(img_height, img_width,3),include_top=False,weights='imagenet')
base_model.trainable = False

#Cria as camadas da Rede Neural Convolucional junto das camadas Fully-Conected(Dense) usando o Sequential do Keras
model = Sequential([
  data_augmentation,
  base_model,
  layers.Flatten(), #Vetoriza as matrizes dos tensores
  layers.Dense(512, activation='relu'), #Primeira camada Fully-Connected 
  layers.Dense(num_classes, activation='softmax')#Camada de saída da Rede, Onde cada  neurônio é uma classe 
])
#Define qual será a função de perda e qual será o modelo de optimização do Back-propagation
model.compile(optimizer='adam', #Utiliza do algoritmo otimizador Adaptative Moment estimation para as camadas convolucionais 
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),  #Utiliza da função de perda Cross Entropy para a parte Fully-Connected da rede
              metrics=['accuracy'])
model.build((None, 128, 128, 3)) #Executa as camadas 
model.summary(expand_nested=True) #Printa como estão alocadas as camadas da rede
# Out:
# Found 4999 files belonging to 5 classes.
# Using 4000 files for training.
# Found 4999 files belonging to 5 classes.
# Using 999 files for validation.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 128, 128, 3)       0
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | random_flip (RandomFlip)  (None, 128, 128, 3)       0         |
# |                                                               |
# | random_rotation (RandomRota  (None, 128, 128, 3)    0         |
# | tion)                                                         |
# |                                                               |
# | random_zoom (RandomZoom)  (None, 128, 128, 3)       0         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  mobilenetv2_1.00_128 (Funct  (None, 4, 4, 1280)       2257984
#  ional)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_1 (InputLayer)      [(None, 128, 128, 3)]     0         |
# |                                                               |
# | Conv1 (Conv2D)            (None, 64, 64, 32)        864       |
# |                                                               |
# | bn_Conv1 (BatchNormalizatio  (None, 64, 64, 32)     128       |
# | n)                                                            |
# |                                                               |
# | Conv1_relu (ReLU)         (None, 64, 64, 32)        0         |
# |                                                               |
# | expanded_conv_depthwise (De  (None, 64, 64, 32)     288       |
# | pthwiseConv2D)                                                |
# |                                                               |
# | expanded_conv_depthwise_BN   (None, 64, 64, 32)     128       |
# | (BatchNormalization)                                          |
# |                                                               |
# | expanded_conv_depthwise_rel  (None, 64, 64, 32)     0         |
# | u (ReLU)                                                      |
# |                                                               |
# | expanded_conv_project (Conv  (None, 64, 64, 16)     512       |
# | 2D)                                                           |
# |                                                               |
# | expanded_conv_project_BN (B  (None, 64, 64, 16)     64        |
# | atchNormalization)                                            |
# |                                                               |
# | block_1_expand (Conv2D)   (None, 64, 64, 96)        1536      |
# |                                                               |
# | block_1_expand_BN (BatchNor  (None, 64, 64, 96)     384       |
# | malization)                                                   |
# |                                                               |
# | block_1_expand_relu (ReLU)  (None, 64, 64, 96)      0         |
# |                                                               |
# | block_1_pad (ZeroPadding2D)  (None, 65, 65, 96)     0         |
# |                                                               |
# | block_1_depthwise (Depthwis  (None, 32, 32, 96)     864       |
# | eConv2D)                                                      |
# |                                                               |
# | block_1_depthwise_BN (Batch  (None, 32, 32, 96)     384       |
# | Normalization)                                                |
# |                                                               |
# | block_1_depthwise_relu (ReL  (None, 32, 32, 96)     0         |
# | U)                                                            |
# |                                                               |
# | block_1_project (Conv2D)  (None, 32, 32, 24)        2304      |
# |                                                               |
# | block_1_project_BN (BatchNo  (None, 32, 32, 24)     96        |
# | rmalization)                                                  |
# |                                                               |
# | block_2_expand (Conv2D)   (None, 32, 32, 144)       3456      |
# |                                                               |
# | block_2_expand_BN (BatchNor  (None, 32, 32, 144)    576       |
# | malization)                                                   |
# |                                                               |
# | block_2_expand_relu (ReLU)  (None, 32, 32, 144)     0         |
# |                                                               |
# | block_2_depthwise (Depthwis  (None, 32, 32, 144)    1296      |
# | eConv2D)                                                      |
# |                                                               |
# | block_2_depthwise_BN (Batch  (None, 32, 32, 144)    576       |
# | Normalization)                                                |
# |                                                               |
# | block_2_depthwise_relu (ReL  (None, 32, 32, 144)    0         |
# | U)                                                            |
# |                                                               |
# | block_2_project (Conv2D)  (None, 32, 32, 24)        3456      |
# |                                                               |
# | block_2_project_BN (BatchNo  (None, 32, 32, 24)     96        |
# | rmalization)                                                  |
# |                                                               |
# | block_2_add (Add)         (None, 32, 32, 24)        0         |
# |                                                               |
# | block_3_expand (Conv2D)   (None, 32, 32, 144)       3456      |
# |                                                               |
# | block_3_expand_BN (BatchNor  (None, 32, 32, 144)    576       |
# | malization)                                                   |
# |                                                               |
# | block_3_expand_relu (ReLU)  (None, 32, 32, 144)     0         |
# |                                                               |
# | block_3_pad (ZeroPadding2D)  (None, 33, 33, 144)    0         |
# |                                                               |
# | block_3_depthwise (Depthwis  (None, 16, 16, 144)    1296      |
# | eConv2D)                                                      |
# |                                                               |
# | block_3_depthwise_BN (Batch  (None, 16, 16, 144)    576       |
# | Normalization)                                                |
# |                                                               |
# | block_3_depthwise_relu (ReL  (None, 16, 16, 144)    0         |
# | U)                                                            |
# |                                                               |
# | block_3_project (Conv2D)  (None, 16, 16, 32)        4608      |
# |                                                               |
# | block_3_project_BN (BatchNo  (None, 16, 16, 32)     128       |
# | rmalization)                                                  |
# |                                                               |
# | block_4_expand (Conv2D)   (None, 16, 16, 192)       6144      |
# |                                                               |
# | block_4_expand_BN (BatchNor  (None, 16, 16, 192)    768       |
# | malization)                                                   |
# |                                                               |
# | block_4_expand_relu (ReLU)  (None, 16, 16, 192)     0         |
# |                                                               |
# | block_4_depthwise (Depthwis  (None, 16, 16, 192)    1728      |
# | eConv2D)                                                      |
# |                                                               |
# | block_4_depthwise_BN (Batch  (None, 16, 16, 192)    768       |
# | Normalization)                                                |
# |                                                               |
# | block_4_depthwise_relu (ReL  (None, 16, 16, 192)    0         |
# | U)                                                            |
# |                                                               |
# | block_4_project (Conv2D)  (None, 16, 16, 32)        6144      |
# |                                                               |
# | block_4_project_BN (BatchNo  (None, 16, 16, 32)     128       |
# | rmalization)                                                  |
# |                                                               |
# | block_4_add (Add)         (None, 16, 16, 32)        0         |
# |                                                               |
# | block_5_expand (Conv2D)   (None, 16, 16, 192)       6144      |
# |                                                               |
# | block_5_expand_BN (BatchNor  (None, 16, 16, 192)    768       |
# | malization)                                                   |
# |                                                               |
# | block_5_expand_relu (ReLU)  (None, 16, 16, 192)     0         |
# |                                                               |
# | block_5_depthwise (Depthwis  (None, 16, 16, 192)    1728      |
# | eConv2D)                                                      |
# |                                                               |
# | block_5_depthwise_BN (Batch  (None, 16, 16, 192)    768       |
# | Normalization)                                                |
# |                                                               |
# | block_5_depthwise_relu (ReL  (None, 16, 16, 192)    0         |
# | U)                                                            |
# |                                                               |
# | block_5_project (Conv2D)  (None, 16, 16, 32)        6144      |
# |                                                               |
# | block_5_project_BN (BatchNo  (None, 16, 16, 32)     128       |
# | rmalization)                                                  |
# |                                                               |
# | block_5_add (Add)         (None, 16, 16, 32)        0         |
# |                                                               |
# | block_6_expand (Conv2D)   (None, 16, 16, 192)       6144      |
# |                                                               |
# | block_6_expand_BN (BatchNor  (None, 16, 16, 192)    768       |
# | malization)                                                   |
# |                                                               |
# | block_6_expand_relu (ReLU)  (None, 16, 16, 192)     0         |
# |                                                               |
# | block_6_pad (ZeroPadding2D)  (None, 17, 17, 192)    0         |
# |                                                               |
# | block_6_depthwise (Depthwis  (None, 8, 8, 192)      1728      |
# | eConv2D)                                                      |
# |                                                               |
# | block_6_depthwise_BN (Batch  (None, 8, 8, 192)      768       |
# | Normalization)                                                |
# |                                                               |
# | block_6_depthwise_relu (ReL  (None, 8, 8, 192)      0         |
# | U)                                                            |
# |                                                               |
# | block_6_project (Conv2D)  (None, 8, 8, 64)          12288     |
# |                                                               |
# | block_6_project_BN (BatchNo  (None, 8, 8, 64)       256       |
# | rmalization)                                                  |
# |                                                               |
# | block_7_expand (Conv2D)   (None, 8, 8, 384)         24576     |
# |                                                               |
# | block_7_expand_BN (BatchNor  (None, 8, 8, 384)      1536      |
# | malization)                                                   |
# |                                                               |
# | block_7_expand_relu (ReLU)  (None, 8, 8, 384)       0         |
# |                                                               |
# | block_7_depthwise (Depthwis  (None, 8, 8, 384)      3456      |
# | eConv2D)                                                      |
# |                                                               |
# | block_7_depthwise_BN (Batch  (None, 8, 8, 384)      1536      |
# | Normalization)                                                |
# |                                                               |
# | block_7_depthwise_relu (ReL  (None, 8, 8, 384)      0         |
# | U)                                                            |
# |                                                               |
# | block_7_project (Conv2D)  (None, 8, 8, 64)          24576     |
# |                                                               |
# | block_7_project_BN (BatchNo  (None, 8, 8, 64)       256       |
# | rmalization)                                                  |
# |                                                               |
# | block_7_add (Add)         (None, 8, 8, 64)          0         |
# |                                                               |
# | block_8_expand (Conv2D)   (None, 8, 8, 384)         24576     |
# |                                                               |
# | block_8_expand_BN (BatchNor  (None, 8, 8, 384)      1536      |
# | malization)                                                   |
# |                                                               |
# | block_8_expand_relu (ReLU)  (None, 8, 8, 384)       0         |
# |                                                               |
# | block_8_depthwise (Depthwis  (None, 8, 8, 384)      3456      |
# | eConv2D)                                                      |
# |                                                               |
# | block_8_depthwise_BN (Batch  (None, 8, 8, 384)      1536      |
# | Normalization)                                                |
# |                                                               |
# | block_8_depthwise_relu (ReL  (None, 8, 8, 384)      0         |
# | U)                                                            |
# |                                                               |
# | block_8_project (Conv2D)  (None, 8, 8, 64)          24576     |
# |                                                               |
# | block_8_project_BN (BatchNo  (None, 8, 8, 64)       256       |
# | rmalization)                                                  |
# |                                                               |
# | block_8_add (Add)         (None, 8, 8, 64)          0         |
# |                                                               |
# | block_9_expand (Conv2D)   (None, 8, 8, 384)         24576     |
# |                                                               |
# | block_9_expand_BN (BatchNor  (None, 8, 8, 384)      1536      |
# | malization)                                                   |
# |                                                               |
# | block_9_expand_relu (ReLU)  (None, 8, 8, 384)       0         |
# |                                                               |
# | block_9_depthwise (Depthwis  (None, 8, 8, 384)      3456      |
# | eConv2D)                                                      |
# |                                                               |
# | block_9_depthwise_BN (Batch  (None, 8, 8, 384)      1536      |
# | Normalization)                                                |
# |                                                               |
# | block_9_depthwise_relu (ReL  (None, 8, 8, 384)      0         |
# | U)                                                            |
# |                                                               |
# | block_9_project (Conv2D)  (None, 8, 8, 64)          24576     |
# |                                                               |
# | block_9_project_BN (BatchNo  (None, 8, 8, 64)       256       |
# | rmalization)                                                  |
# |                                                               |
# | block_9_add (Add)         (None, 8, 8, 64)          0         |
# |                                                               |
# | block_10_expand (Conv2D)  (None, 8, 8, 384)         24576     |
# |                                                               |
# | block_10_expand_BN (BatchNo  (None, 8, 8, 384)      1536      |
# | rmalization)                                                  |
# |                                                               |
# | block_10_expand_relu (ReLU)  (None, 8, 8, 384)      0         |
# |                                                               |
# | block_10_depthwise (Depthwi  (None, 8, 8, 384)      3456      |
# | seConv2D)                                                     |
# |                                                               |
# | block_10_depthwise_BN (Batc  (None, 8, 8, 384)      1536      |
# | hNormalization)                                               |
# |                                                               |
# | block_10_depthwise_relu (Re  (None, 8, 8, 384)      0         |
# | LU)                                                           |
# |                                                               |
# | block_10_project (Conv2D)  (None, 8, 8, 96)         36864     |
# |                                                               |
# | block_10_project_BN (BatchN  (None, 8, 8, 96)       384       |
# | ormalization)                                                 |
# |                                                               |
# | block_11_expand (Conv2D)  (None, 8, 8, 576)         55296     |
# |                                                               |
# | block_11_expand_BN (BatchNo  (None, 8, 8, 576)      2304      |
# | rmalization)                                                  |
# |                                                               |
# | block_11_expand_relu (ReLU)  (None, 8, 8, 576)      0         |
# |                                                               |
# | block_11_depthwise (Depthwi  (None, 8, 8, 576)      5184      |
# | seConv2D)                                                     |
# |                                                               |
# | block_11_depthwise_BN (Batc  (None, 8, 8, 576)      2304      |
# | hNormalization)                                               |
# |                                                               |
# | block_11_depthwise_relu (Re  (None, 8, 8, 576)      0         |
# | LU)                                                           |
# |                                                               |
# | block_11_project (Conv2D)  (None, 8, 8, 96)         55296     |
# |                                                               |
# | block_11_project_BN (BatchN  (None, 8, 8, 96)       384       |
# | ormalization)                                                 |
# |                                                               |
# | block_11_add (Add)        (None, 8, 8, 96)          0         |
# |                                                               |
# | block_12_expand (Conv2D)  (None, 8, 8, 576)         55296     |
# |                                                               |
# | block_12_expand_BN (BatchNo  (None, 8, 8, 576)      2304      |
# | rmalization)                                                  |
# |                                                               |
# | block_12_expand_relu (ReLU)  (None, 8, 8, 576)      0         |
# |                                                               |
# | block_12_depthwise (Depthwi  (None, 8, 8, 576)      5184      |
# | seConv2D)                                                     |
# |                                                               |
# | block_12_depthwise_BN (Batc  (None, 8, 8, 576)      2304      |
# | hNormalization)                                               |
# |                                                               |
# | block_12_depthwise_relu (Re  (None, 8, 8, 576)      0         |
# | LU)                                                           |
# |                                                               |
# | block_12_project (Conv2D)  (None, 8, 8, 96)         55296     |
# |                                                               |
# | block_12_project_BN (BatchN  (None, 8, 8, 96)       384       |
# | ormalization)                                                 |
# |                                                               |
# | block_12_add (Add)        (None, 8, 8, 96)          0         |
# |                                                               |
# | block_13_expand (Conv2D)  (None, 8, 8, 576)         55296     |
# |                                                               |
# | block_13_expand_BN (BatchNo  (None, 8, 8, 576)      2304      |
# | rmalization)                                                  |
# |                                                               |
# | block_13_expand_relu (ReLU)  (None, 8, 8, 576)      0         |
# |                                                               |
# | block_13_pad (ZeroPadding2D  (None, 9, 9, 576)      0         |
# | )                                                             |
# |                                                               |
# | block_13_depthwise (Depthwi  (None, 4, 4, 576)      5184      |
# | seConv2D)                                                     |
# |                                                               |
# | block_13_depthwise_BN (Batc  (None, 4, 4, 576)      2304      |
# | hNormalization)                                               |
# |                                                               |
# | block_13_depthwise_relu (Re  (None, 4, 4, 576)      0         |
# | LU)                                                           |
# |                                                               |
# | block_13_project (Conv2D)  (None, 4, 4, 160)        92160     |
# |                                                               |
# | block_13_project_BN (BatchN  (None, 4, 4, 160)      640       |
# | ormalization)                                                 |
# |                                                               |
# | block_14_expand (Conv2D)  (None, 4, 4, 960)         153600    |
# |                                                               |
# | block_14_expand_BN (BatchNo  (None, 4, 4, 960)      3840      |
# | rmalization)                                                  |
# |                                                               |
# | block_14_expand_relu (ReLU)  (None, 4, 4, 960)      0         |
# |                                                               |
# | block_14_depthwise (Depthwi  (None, 4, 4, 960)      8640      |
# | seConv2D)                                                     |
# |                                                               |
# | block_14_depthwise_BN (Batc  (None, 4, 4, 960)      3840      |
# | hNormalization)                                               |
# |                                                               |
# | block_14_depthwise_relu (Re  (None, 4, 4, 960)      0         |
# | LU)                                                           |
# |                                                               |
# | block_14_project (Conv2D)  (None, 4, 4, 160)        153600    |
# |                                                               |
# | block_14_project_BN (BatchN  (None, 4, 4, 160)      640       |
# | ormalization)                                                 |
# |                                                               |
# | block_14_add (Add)        (None, 4, 4, 160)         0         |
# |                                                               |
# | block_15_expand (Conv2D)  (None, 4, 4, 960)         153600    |
# |                                                               |
# | block_15_expand_BN (BatchNo  (None, 4, 4, 960)      3840      |
# | rmalization)                                                  |
# |                                                               |
# | block_15_expand_relu (ReLU)  (None, 4, 4, 960)      0         |
# |                                                               |
# | block_15_depthwise (Depthwi  (None, 4, 4, 960)      8640      |
# | seConv2D)                                                     |
# |                                                               |
# | block_15_depthwise_BN (Batc  (None, 4, 4, 960)      3840      |
# | hNormalization)                                               |
# |                                                               |
# | block_15_depthwise_relu (Re  (None, 4, 4, 960)      0         |
# | LU)                                                           |
# |                                                               |
# | block_15_project (Conv2D)  (None, 4, 4, 160)        153600    |
# |                                                               |
# | block_15_project_BN (BatchN  (None, 4, 4, 160)      640       |
# | ormalization)                                                 |
# |                                                               |
# | block_15_add (Add)        (None, 4, 4, 160)         0         |
# |                                                               |
# | block_16_expand (Conv2D)  (None, 4, 4, 960)         153600    |
# |                                                               |
# | block_16_expand_BN (BatchNo  (None, 4, 4, 960)      3840      |
# | rmalization)                                                  |
# |                                                               |
# | block_16_expand_relu (ReLU)  (None, 4, 4, 960)      0         |
# |                                                               |
# | block_16_depthwise (Depthwi  (None, 4, 4, 960)      8640      |
# | seConv2D)                                                     |
# |                                                               |
# | block_16_depthwise_BN (Batc  (None, 4, 4, 960)      3840      |
# | hNormalization)                                               |
# |                                                               |
# | block_16_depthwise_relu (Re  (None, 4, 4, 960)      0         |
# | LU)                                                           |
# |                                                               |
# | block_16_project (Conv2D)  (None, 4, 4, 320)        307200    |
# |                                                               |
# | block_16_project_BN (BatchN  (None, 4, 4, 320)      1280      |
# | ormalization)                                                 |
# |                                                               |
# | Conv_1 (Conv2D)           (None, 4, 4, 1280)        409600    |
# |                                                               |
# | Conv_1_bn (BatchNormalizati  (None, 4, 4, 1280)     5120      |
# | on)                                                           |
# |                                                               |
# | out_relu (ReLU)           (None, 4, 4, 1280)        0         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  flatten (Flatten)           (None, 20480)             0
#
#  dense (Dense)               (None, 512)               10486272
#
#  dense_1 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 12,746,821
# Trainable params: 10,488,837
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
#Faz o treinamento da rede utilizando do modelo criado 
epochs=200
history = model.fit(
  train_ds, #Dataset de treinamento
  validation_data=val_ds, #Dataset de validação
  epochs=epochs #Número de épocas 
)
# Out:
# Epoch 1/200
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
#
200
# 125/125 [==============================] - 18s 146ms/step - loss: 0.1103 - accuracy: 0.9615 - val_loss: 1.7442 - val_accuracy: 0.6997
# Epoch 199/200
# 125/125 [==============================] - 18s 147ms/step - loss: 0.1319 - accuracy: 0.9532 - val_loss: 1.8379 - val_accuracy: 0.6837
# Epoch 200/200
# 125/125 [==============================] - 18s 146ms/step - loss: 0.1357 - accuracy: 0.9523 - val_loss: 1.7011 - val_accuracy: 0.6987

# %%
print(history.history['val_accuracy'])
# Out:
# [0.6899999976158142, 0.7544000148773193, 0.7997999787330627, 0.751800000667572, 0.7333999872207642, 0.8330000042915344, 0.8601999878883362, 0.7214000225067139, 0.817799985408783, 0.8863999843597412, 0.8123999834060669, 0.8068000078201294, 0.881600022315979, 0.8827999830245972, 0.7781999707221985, 0.9164000153541565, 0.9175999760627747, 0.8996000289916992, 0.8902000188827515, 0.8980000019073486, 0.8895999789237976, 0.909600019454956, 0.8962000012397766, 0.8845999836921692, 0.8885999917984009, 0.8759999871253967, 0.8823999762535095, 0.9121999740600586, 0.8999999761581421, 0.9028000235557556]

# %%
#Faz um gráfico utilizando da Acurácia e da Perda entre os dados de Treinamento e os Dados de Validação
plt.figure(figsize=(16, 4)) #Tamanho da imagem

plt.subplot(1, 2, 1) #Tamanho da Sub-Imagem da Esquerda
plt.plot(range(epochs), history.history['accuracy'], label='Training Accuracy') #Dados de Acurácia dos dados de treino para sub-imagem da esquerda
plt.plot(range(epochs),  history.history['val_accuracy'], label='Validation Accuracy') #Dados de Acurácia dos dados de validação para sub-imagem da esquerda
plt.legend(loc='lower right') #Local da legenda da sub-imagem da esquerda
plt.title('Training and Validation Accuracy') #Título da sub-imagem da esquerda

plt.subplot(1, 2, 2) #Tamanho da Sub-Imagem da Direita
plt.plot(range(epochs), history.history['loss'], label='Training Loss') #Dados da Perda dos dados de treino para sub-imagem da direita
plt.plot(range(epochs), history.history['val_loss'], label='Validation Loss') #Dados da Perda dos dados de validação para sub-imagem direita
plt.legend(loc='upper left') #Local da legenda da sub-imagem da direita
plt.title('Training and Validation Loss') #Título da sub-imagem da direita 
plt.show()

# %%
orchids = list(data_dir.glob('Orchid/*')) #Carrega todas as imagens das rosas do Dataset em uma lista
lotus = list(data_dir.glob('Lotus/*')) #Carrega todas as imagens dos dentes de leão do Dataset em uma lista
tulips = list(data_dir.glob('Tulip/*')) #Carrega todas as imagens das tulipas do Dataset em uma lista
sunflowers = list(data_dir.glob('Sunflower/*')) #Carrega todas as imagens dos girassoís do Dataset em uma lista
lillys = list(data_dir.glob('Lilly/*')) #Carrega todas as imagens das margaridas do Dataset em uma lista
im = PIL.Image.open(lillys[110])

# %%
#im = PIL.Image.open('C:/Users/davic/Downloads/Tulips.JPEG') #Carrega uma das imagens em uma variável
plt.imshow(im) #Printa a imagem
im = im.resize((128,128)) #Rescala a Imagem no formato 180x180
im_array = np.array(im) #Vetoriza a imagem no formato 180x180
im_array = np.expand_dims(im_array, axis = 0) #Rescalona a imagem no formato 180x180x1 para ficar no estilo do Keras/TEnsorFlow
score = model.predict(im_array) #Faz a predição da imagem

print("Essa imagem pertence a classe {} com {:.2f} porcento de predicão.".format(class_names[np.argmax(score)], 100 * np.max(score))) #Printa o score da imagem dizendo a qual classe ela pertence
# Out:
# 1/1 [==============================] - 1s 534ms/step
# Essa imagem pertence a classe Lilly com 96.57 porcento de predicão.
